# %%
# Sunny's Diwali Sales Analysis Imports
# Project by Sunny | Data Analysis & Visualization | 2025
# Let's load all the libraries we need for data analysis and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')  # Custom style for all plots
plt.rcParams['figure.facecolor'] = '#f7f7fa'  # Light background for all figures

# %%
# import csv file
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
# change data type
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
df.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %%
# Gender Distribution Visualization
plt.figure(figsize=(8,5))
ax = sns.countplot(x='Gender', data=df, palette='Set2', edgecolor='black')
plt.title('Distribution of Buyers by Gender', fontsize=16, color='#2a2a2a')
plt.xlabel('Gender', fontsize=13)
plt.ylabel('Number of Buyers', fontsize=13)
for bars in ax.containers:
    ax.bar_label(bars, fontsize=12, color='#333')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sunny\AppData\Local\Temp\ipykernel_1776\2262120783.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Gender', data=df, palette='Set2', edgecolor='black')

# %%
# Total Purchase Amount by Gender
gender_amount = df.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
plt.figure(figsize=(8,5))
ax2 = sns.barplot(x='Gender', y='Amount', data=gender_amount, palette='coolwarm', edgecolor='black')
plt.title('Total Purchase Amount by Gender', fontsize=16, color='#2a2a2a')
plt.xlabel('Gender', fontsize=13)
plt.ylabel('Total Amount Spent', fontsize=13)
for bars in ax2.containers:
    ax2.bar_label(bars, fontsize=12, color='#333')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sunny\AppData\Local\Temp\ipykernel_1776\3229253566.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.barplot(x='Gender', y='Amount', data=gender_amount, palette='coolwarm', edgecolor='black')

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
# Age Group Distribution by Gender
plt.figure(figsize=(10,6))
age_gender_plot = sns.countplot(x='Age Group', hue='Gender', data=df, palette='mako', edgecolor='black')
plt.title('Buyers by Age Group and Gender', fontsize=16, color='#2a2a2a')
plt.xlabel('Age Group', fontsize=13)
plt.ylabel('Number of Buyers', fontsize=13)
for bars in age_gender_plot.containers:
    age_gender_plot.bar_label(bars, fontsize=12, color='#333')
plt.tight_layout()
plt.show()

# %%
# Total Purchase Amount by Age Group
agegroup_amount = df.groupby('Age Group', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
plt.figure(figsize=(10,6))
age_amount_plot = sns.barplot(x='Age Group', y='Amount', data=agegroup_amount, palette='viridis', edgecolor='black')
plt.title('Total Purchase Amount by Age Group', fontsize=16, color='#2a2a2a')
plt.xlabel('Age Group', fontsize=13)
plt.ylabel('Total Amount Spent', fontsize=13)
for bars in age_amount_plot.containers:
    age_amount_plot.bar_label(bars, fontsize=12, color='#333')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sunny\AppData\Local\Temp\ipykernel_1776\3329026716.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   age_amount_plot = sns.barplot(x='Age Group', y='Amount', data=agegroup_amount, palette='viridis', edgecolor='black')

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# ### State

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
# Top 10 most sold products (bar chart with glassy blue/green colors)
fig1, ax1 = plt.subplots(figsize=(12,7))
bar_colors = ['#4fc3f7' if i%2==0 else '#81c784' for i in range(10)]
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar', color=bar_colors, edgecolor='black', alpha=0.85, ax=ax1)
plt.title('Top 10 Most Sold Products', fontsize=16, color='#2a2a2a')
plt.xlabel('Product ID', fontsize=13)
plt.ylabel('Number of Orders', fontsize=13)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
#
# ### Key Insights from Sunny's Diwali Sales Analysis

# %% [markdown]
# *Most purchases are made by women aged 26-35, especially those who are married and working in IT, Healthcare, or Aviation. Uttar Pradesh, Maharashtra, and Karnataka are the top states for sales. Food, Clothing, and Electronics are the most popular product categories.*
#
# This analysis was performed and visualized by Sunny in 2025. The insights can help businesses target their marketing and product strategies for future Diwali sales. Thank you for exploring this project!

# %% [markdown]
# Thank you!
# 6
# 5

# %%
# Sunny's Custom Pie Chart (light sky blue & red)
import matplotlib.patches as mpatches
pie_data = df['Gender'].value_counts()
pie_labels = pie_data.index
pie_colors = ['#87ceeb', '#ff5252']  # Light sky blue and red
fig2, ax2 = plt.subplots(figsize=(6,6))
wedges, texts, autotexts = ax2.pie(pie_data, labels=pie_labels, colors=pie_colors, autopct='%1.1f%%', startangle=140, wedgeprops={'edgecolor':'white', 'linewidth':2, 'alpha':0.85})
plt.title('Gender Distribution (Sky Blue & Red)', fontsize=15, color='#2a2a2a')
plt.show()

# Sunny's Custom Line Chart (light sky blue & red)
line_data = df.groupby('Age')['Amount'].sum().sort_index()
fig3, ax3 = plt.subplots(figsize=(8,5))
ax3.plot(line_data.index, line_data.values, color='#87ceeb', linewidth=3, marker='o', alpha=0.85, label='Amount (Sky Blue)')
ax3.plot(line_data.index, line_data.values*0.8, color='#ff5252', linewidth=2, marker='s', alpha=0.85, label='Amount (Red)')
plt.title('Amount Spent by Age (Sky Blue & Red)', fontsize=15, color='#2a2a2a')
plt.xlabel('Age', fontsize=13)
plt.ylabel('Total Amount', fontsize=13)
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
